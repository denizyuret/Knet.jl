# %%
include("vae_mnist.jl")
# Out:
# VAE

# %%
# obtain a non-trained network
θ, ϕ = VAE.main("--infotime 10 --seed 1 --epochs 0");
# Out:
# INFO: using Knet.KnetArray{Float32,N} where N
# (:epoch, 0, :trn,
# INFO: Loading MNIST...
# 0.69387156f0, :tst, 0.69387734f0)
#   0.000008 seconds (1 allocation: 32 bytes)

# %%
# generate examples with the non-trained network
VAE.plot_dream(θ);
# Out:
# 426×426 Array{Gray{Float64},2}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)       …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.475546)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.475546)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.47905)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.482555)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.48606)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.484845)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.48363)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.482415)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.495589)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.508763)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.521937)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.511693)     Gray{Float64}(1.0)
#  ⋮                                            ⋱  ⋮
#  Gray{Float64}(1.0)  Gray{Float64}(0.470915)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.489178)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.507442)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.525705)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.514653)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.5036)       Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.492548)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.495297)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.498046)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.500794)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(0.500794)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)       …  Gray{Float64}(1.0)

# %%
# train a VAE network for 100 epochs
θ, ϕ = VAE.main("--infotime 10 --seed 1 --epochs 100");
# Out:
# INFO: using Knet.KnetArray{Float32,N} where N
# INFO: Loading MNIST...
# (:epoch, 0, :trn, 0.6938733f0, :tst, 0.6938929f0)
# (:epoch, 10, :trn, 0.13422799f0, :tst, 0.13388626f0)
# elapsed time: 19.202212801 seconds
# (:epoch, 20, :trn, 0.1317165f0, :tst, 0.13167857f0)
# elapsed time: 15.649525381 seconds
# (:epoch, 30, :trn, 0.13075511f0, :tst, 0.13100834f0)
# elapsed time: 15.758460639 seconds
# (:epoch, 40, :trn, 0.12976673f0, :tst, 0.13016598f0)
# elapsed time: 15.648266332 seconds
# (:epoch, 50, :trn, 0.1295722f0, :tst, 0.12997805f0)
# elapsed time: 15.656436908 seconds
# (:epoch, 60, :trn, 0.12869303f0, :tst, 0.12916964f0)
# elapsed time: 15.6570503 seconds
# (:epoch, 70, :trn, 0.12857209f0, :tst, 0.1289829f0)
# elapsed time: 15.660806413 seconds
# (:epoch, 80, :trn, 0.12823705f0, :tst, 0.12879342f0)
# elapsed time: 15.665658112 seconds
# (:epoch, 90, :trn, 0.1279789f0, :tst, 0.12858301f0)
# elapsed time: 15.65942621 seconds
# (:epoch, 100, :trn, 0.1277539f0, :tst, 0.1283781f0)
# elapsed time: 15.662846264 seconds
# 160.262027 seconds (142.58 M allocations: 24.483 GiB, 1.57% gc time)

# %%
# generate examples with the trained network
VAE.plot_dream(θ);
# Out:
# 426×426 Array{Gray{Float64},2}:
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.93964e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.93964e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.70287e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.46611e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.22935e-11)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.39494e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.56052e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.72611e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.78561e-11)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.8451e-11)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.9046e-11)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.87173e-11)     Gray{Float64}(1.0)
#  ⋮                                               ⋱  ⋮
#  Gray{Float64}(1.0)  Gray{Float64}(5.32782e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(4.63675e-16)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(3.94567e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(3.2546e-16)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(3.22993e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(3.20526e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(3.18059e-16)  …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(4.66294e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(6.14529e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(7.62764e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(7.62764e-16)     Gray{Float64}(1.0)
#  Gray{Float64}(1.0)  Gray{Float64}(1.0)          …  Gray{Float64}(1.0)
