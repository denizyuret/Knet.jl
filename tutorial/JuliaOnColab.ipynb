# %% [markdown]
# ## Julia on Colaboratory ##
#
# [Colaboratory](https://colab.research.google.com) does not provide native support for the [Julia programming language](https://julialang.org). However, since Colaboratory gives you root access to the machine that runs your notebook (the *“runtime”* in Colaboratory terminology), we can install Julia support by uploading a specially crafted Julia notebook  – *this* notebook. We then install Julia and [IJulia](https://github.com/JuliaLang/IJulia.jl) ([Jupyter](https://jupyter.org)/Colaboratory notebook support) and reload the notebook so that Colaboratory detects and initiates what we installed.
#
# In brief:
#
# 1. **Run the cell below**
# 2. **Reload the page**
# 3. **Edit the notebook name and start hacking Julia code below**
#
# **If your runtime resets**, either manually or if left idle for some time, **repeat steps 1 and 2**.
#
# ### Acknowledgements ###
#
# This hack by Pontus Stenetorp is an adaptation of [James Bradbury’s original Colaboratory Julia hack](https://discourse.julialang.org/t/julia-on-google-colab-free-gpu-accelerated-shareable-notebooks/15319/27), that broke some time in September 2019 as Colaboratory increased their level of notebook runtime isolation. There also appears to be CUDA compilation support installed by default for each notebook runtime type in October 2019, which shaves off a good 15 minutes or so from the original hack’s installation time.

# %%
# Installation cell
%%shell
if ! command -v julia 2>&1 > /dev/null
then
    wget 'https://julialang-s3.julialang.org/bin/linux/x64/1.2/julia-1.2.0-linux-x86_64.tar.gz' \
        -O /tmp/julia.tar.gz
    tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
    rm /tmp/julia.tar.gz
fi
julia -e 'using Pkg; pkg"add Plots; add PyPlot; add IJulia; add Knet; precompile"'
julia -e 'using Pkg; pkg"build Knet;"'
# Out:
# --2019-11-12 07:11:03--  https://julialang-s3.julialang.org/bin/linux/x64/1.2/julia-1.2.0-linux-x86_64.tar.gz
# Resolving julialang-s3.julialang.org (julialang-s3.julialang.org)... 151.101.2.49, 151.101.66.49, 151.101.130.49, ...
# Connecting to julialang-s3.julialang.org (julialang-s3.julialang.org)|151.101.2.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91990555 (88M) [application/x-tar]
# Saving to: ‘/tmp/julia.tar.gz’
#
# /tmp/julia.tar.gz   100%[===================>]  87.73M   330MB/s    in 0.3s
#
# 2019-11-12 07:11:11 (330 MB/s) - ‘/tmp/julia.tar.gz’ saved [91990555/91990555]
#
#    Cloning default registries into `~/.julia`
#    Cloning registry from "https://github.com/JuliaRegistries/General.git"
#      Added registry `General` to `~/.julia/registries/General`
#  Resolving package versions...
#  Installed Missings ─────────── v0.4.3
#  Installed Showoff ──────────── v0.3.1
#  Installed DataAPI ──────────── v1.1.0
#  Installed BinaryProvider ───── v0.5.8
#  Installed Plots ────────────── v0.27.0
#  Installed StatsBase ────────── v0.32.0
#  Installed Contour ──────────── v0.5.1
#  Installed Colors ───────────── v0.9.6
#  Installed Reexport ─────────── v0.2.0
#  Installed Requires ─────────── v0.5.2
#  Installed OrderedCollections ─ v1.1.0
#  Installed Compat ───────────── v2.2.0
#  Installed IterTools ────────── v1.2.0
#  Installed Measures ─────────── v0.3.0
#  Installed RecipesBase ──────── v0.7.0
#  Installed DataStructures ───── v0.17.5
#  Installed Parsers ──────────── v0.3.8
#  Installed FFMPEG ───────────── v0.2.3
#  Installed NaNMath ──────────── v0.3.2
#  Installed FixedPointNumbers ── v0.6.1
#  Installed JSON ─────────────── v0.21.0
#  Installed GeometryTypes ────── v0.7.6
#  Installed StaticArrays ─────── v0.12.1
#  Installed PlotThemes ───────── v0.4.0
#  Installed SortingAlgorithms ── v0.3.1
#  Installed PlotUtils ────────── v0.6.0
#  Installed ColorTypes ───────── v0.8.0
#  Installed GR ───────────────── v0.42.0
#   Updating `~/.julia/environments/v1.2/Project.toml`
#   [91a5bcdd] + Plots v0.27.0
#   Updating `~/.julia/environments/v1.2/Manifest.toml`
#   [b99e7846] + BinaryProvider v0.5.8
#   [3da002f7] + ColorTypes v0.8.0
#   [5ae59095] + Colors v0.9.6
#   [34da2185] + Compat v2.2.0
#   [d38c429a] + Contour v0.5.1
#   [9a962f9c] + DataAPI v1.1.0
#   [864edb3b] + DataStructures v0.17.5
#   [c87230d0] + FFMPEG v0.2.3
#   [53c48c17] + FixedPointNumbers v0.6.1
#   [28b8d3ca] + GR v0.42.0
#   [4d00f742] + GeometryTypes v0.7.6
#   [c8e1da08] + IterTools v1.2.0
#   [682c06a0] + JSON v0.21.0
#   [442fdcdd] + Measures v0.3.0
#   [e1d29d7a] + Missings v0.4.3
#   [77ba4419] + NaNMath v0.3.2
#   [bac558e1] + OrderedCollections v1.1.0
#   [69de0a69] + Parsers v0.3.8
#   [ccf2f8ad] + PlotThemes v0.4.0
#   [995b91a9] + PlotUtils v0.6.0
#   [91a5bcdd] + Plots v0.27.0
#   [3cdcf5f2] + RecipesBase v0.7.0
#   [189a3867] + Reexport v0.2.0
#   [ae029012] + Requires v0.5.2
#   [992d4aef] + Showoff v0.3.1
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [90137ffa] + StaticArrays v0.12.1
#   [2913bbd2] + StatsBase v0.32.0
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [1a1011a3] + SharedArrays
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   Building GR ────→ `~/.julia/packages/GR/f1Iqi/deps/build.log`
#   Building FFMPEG → `~/.julia/packages/FFMPEG/bkWgb/deps/build.log`
#   Building Plots ─→ `~/.julia/packages/Plots/Iuc9S/deps/build.log`
#  Resolving package versions...
#  Installed VersionParsing ─ v1.1.3
#  Installed Conda ────────── v1.3.0
#  Installed LaTeXStrings ─── v1.0.3
#  Installed CSTParser ────── v1.0.0
#  Installed PyPlot ───────── v2.8.2
#  Installed MacroTools ───── v0.5.1
#  Installed Tokenize ─────── v0.5.6
#  Installed PyCall ───────── v1.91.2
#   Updating `~/.julia/environments/v1.2/Project.toml`
#   [d330b81b] + PyPlot v2.8.2
#   Updating `~/.julia/environments/v1.2/Manifest.toml`
#   [00ebfdb7] + CSTParser v1.0.0
#   [8f4d0f93] + Conda v1.3.0
#   [b964fa9f] + LaTeXStrings v1.0.3
#   [1914dd2f] + MacroTools v0.5.1
#   [438e738f] + PyCall v1.91.2
#   [d330b81b] + PyPlot v2.8.2
#   [0796e94c] + Tokenize v0.5.6
#   [81def892] + VersionParsing v1.1.3
#   Building Conda ─→ `~/.julia/packages/Conda/kLXeC/deps/build.log`
#   Building PyCall → `~/.julia/packages/PyCall/ttONZ/deps/build.log`
#  Resolving package versions...
#  Installed SoftGlobalScope ─ v1.0.10
#  Installed IJulia ────────── v1.20.2
#  Installed ZMQ ───────────── v1.0.0
#  Installed MbedTLS ───────── v0.7.0
#   Updating `~/.julia/environments/v1.2/Project.toml`
#   [7073ff75] + IJulia v1.20.2
#   Updating `~/.julia/environments/v1.2/Manifest.toml`
#   [7073ff75] + IJulia v1.20.2
#   [739be429] + MbedTLS v0.7.0
#   [b85f4697] + SoftGlobalScope v1.0.10
#   [c2297ded] + ZMQ v1.0.0
#   [7b1f6079] + FileWatching
#   Building ZMQ ────→ `~/.julia/packages/ZMQ/ABGOx/deps/build.log`
#   Building MbedTLS → `~/.julia/packages/MbedTLS/a1JFn/deps/build.log`
#   Building IJulia ─→ `~/.julia/packages/IJulia/F1GUo/deps/build.log`
#  Resolving package versions...
#  Installed URIParser ────────── v0.4.0
#  Installed Adapt ────────────── v1.0.0
#  Installed AbstractFFTs ─────── v0.4.1
#  Installed CUDAnative ───────── v2.5.4
#  Installed JLD2 ─────────────── v0.1.3
#  Installed CuArrays ─────────── v1.4.4
#  Installed CUDAdrv ──────────── v4.0.3
#  Installed TimerOutputs ─────── v0.5.1
#  Installed NNlib ────────────── v0.6.0
#  Installed GPUArrays ────────── v2.0.0
#  Installed CUDAapi ──────────── v1.2.0
#  Installed CodecZlib ────────── v0.6.0
#  Installed TranscodingStreams ─ v0.9.5
#  Installed Knet ─────────────── v1.3.1
#  Installed CEnum ────────────── v0.2.0
#  Installed SpecialFunctions ─── v0.8.0
#  Installed LLVM ─────────────── v1.3.2
#  Installed BinDeps ──────────── v0.8.10
#  Installed AutoGrad ─────────── v1.2.0
#  Installed FileIO ───────────── v1.0.7
#   Updating `~/.julia/environments/v1.2/Project.toml`
#   [1902f260] + Knet v1.3.1
#   Updating `~/.julia/environments/v1.2/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.4.1
#   [79e6a3ab] + Adapt v1.0.0
#   [6710c13c] + AutoGrad v1.2.0
#   [9e28174c] + BinDeps v0.8.10
#   [fa961155] + CEnum v0.2.0
#   [3895d2a7] + CUDAapi v1.2.0
#   [c5f51814] + CUDAdrv v4.0.3
#   [be33ccc6] + CUDAnative v2.5.4
#   [944b1d66] + CodecZlib v0.6.0
#   [3a865a2d] + CuArrays v1.4.4
#   [5789e2e9] + FileIO v1.0.7
#   [0c68f7d7] + GPUArrays v2.0.0
#   [033835bb] + JLD2 v0.1.3
#   [1902f260] + Knet v1.3.1
#   [929cbde3] + LLVM v1.3.2
#   [872c559c] + NNlib v0.6.0
#   [276daf66] + SpecialFunctions v0.8.0
#   [a759f4b9] + TimerOutputs v0.5.1
#   [3bb67fe8] + TranscodingStreams v0.9.5
#   [30578b45] + URIParser v0.4.0
#   Building SpecialFunctions → `~/.julia/packages/SpecialFunctions/ne2iw/deps/build.log`
#   Building CodecZlib ───────→ `~/.julia/packages/CodecZlib/5t9zO/deps/build.log`
#   Building Knet ────────────→ `~/.julia/packages/Knet/HRYiN/deps/build.log`
# Precompiling project...
# Precompiling Knet
# WARNING: Method definition project(Any, Any, Any) in module NNlib at /root/.julia/packages/NNlib/mxWRT/src/impl/conv_direct.jl:66 overwritten at /root/.julia/packages/NNlib/mxWRT/src/impl/conv_direct.jl:66.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition project(Any, Any, Any) in module NNlib at /root/.julia/packages/NNlib/mxWRT/src/impl/depthwiseconv_direct.jl:41 overwritten at /root/.julia/packages/NNlib/mxWRT/src/impl/depthwiseconv_direct.jl:41.
#   ** incremental compilation may be fatally broken for this module **
#
# Precompiling IJulia
# Precompiling Plots
# Precompiling PyPlot
#   Building SpecialFunctions → `~/.julia/packages/SpecialFunctions/ne2iw/deps/build.log`
#   Building CodecZlib ───────→ `~/.julia/packages/CodecZlib/5t9zO/deps/build.log`
#   Building Knet ────────────→ `~/.julia/packages/Knet/HRYiN/deps/build.log`

# %%
using Knet
# Test if Knet is using gpu
Knet.gpu()
# Out:
# ┌ Info: Recompiling stale cache file /root/.julia/compiled/v1.2/Knet/f4vSz.ji for Knet [1902f260-5fb4-5aff-8c31-6271790ab950]
# └ @ Base loading.jl:1240
# 0

# %%
a = KnetArray(randn(4,4))
sigm.(a)
# Out:
# 4×4 KnetArray{Float64,2}:
#  0.54592   0.554279  0.343429   0.838957
#  0.806902  0.768127  0.285473   0.488519
#  0.568271  0.857464  0.0606523  0.424611
#  0.53042   0.396642  0.694845   0.125767
